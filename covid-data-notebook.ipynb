# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates


# Load data from URL (or local CSV)
url = "/Users/pdev/Downloads/owid-covid-data.csv"
df = pd.read_csv(url)

# 👉 Set your desired country
country_name = "United States"  # Change this to any country

# Filter the DataFrame for that country
country_df = df[df["location"] == country_name]

# Print the first 100 rows
print("First 100 rows for United States")
print(country_df.head(10))

# Convert 'date' column to datetime
country_df = df[df['location'] == 'India'].copy()
country_df['date'] = pd.to_datetime(country_df['date'])

# Set up the plot
plt.figure(figsize=(14, 6))  # Widen the plot

# Plot daily new cases
plt.plot(country_df['date'], country_df['new_cases'], label='New Cases', color='blue')

# Format the x-axis date labels
#plt.xticks(rotation=45)  # Tilt the labels
#plt.locator_params(axis='x', nbins=15)  # Show fewer ticks (adjust 10–20 as needed)

# Set number of date ticks by using an AutoDateLocator or a more specific one
locator = mdates.AutoDateLocator(minticks=8, maxticks=15)
plt.gca().xaxis.set_major_locator(locator)

# Optional: format the dates
formatter = mdates.DateFormatter('%b %d')  # e.g., 'Jul 18'
plt.gca().xaxis.set_major_formatter(formatter)
plt.xticks(rotation=45)


# Add title and labels
plt.title("Daily New COVID-19 Cases - United States")
plt.xlabel("Date")
plt.ylabel("New Cases")
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# First 100 rows for United States
#        iso_code      continent       location        date  total_cases  \
# 403451      USA  North America  United States  2020-01-05          0.0
# 403452      USA  North America  United States  2020-01-06          0.0
# 403453      USA  North America  United States  2020-01-07          0.0
# 403454      USA  North America  United States  2020-01-08          0.0
# 403455      USA  North America  United States  2020-01-09          0.0
# 403456      USA  North America  United States  2020-01-10          0.0
# 403457      USA  North America  United States  2020-01-11          0.0
# 403458      USA  North America  United States  2020-01-12          0.0
# 403459      USA  North America  United States  2020-01-13          0.0
# 403460      USA  North America  United States  2020-01-14          0.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 403451        0.0                 NaN           0.0         0.0
# ...
